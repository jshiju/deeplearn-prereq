# %%
# Many famous machine learning datasets are image datasets
# Mnist, Cifar10

# %%
# retrieve image using wget
#!wget https://github.com/lazyprogrammer/machine_learning_examples/blob/master/cnn_class/lena.png
# Out:
# --2023-12-10 07:39:32--  https://github.com/lazyprogrammer/machine_learning_examples/blob/master/cnn_class/lena.png
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8930 (8.7K) [text/plain]
# Saving to: ‘lena.png.2’
#
# lena.png.2          100%[===================>]   8.72K  --.-KB/s    in 0s
#
# 2023-12-10 07:39:32 (21.9 MB/s) - ‘lena.png.2’ saved [8930/8930]

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
im = Image.open('butterfly.png')
# im.show()

# %%
type(im)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
ia = np.array(im)
ia.shape
# Out:
# (2755, 2900, 4)

# %%
plt.imshow(ia);
