# %%
# Convolution is a mathematical operation on two functions (f and g) that produces 
# a third function (f*g) that expresses how the shape of one is modified by the other

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from scipy.stats import norm

# %%
im = Image.open('../images/tamanna.png')

# %%
gray = np.mean(im, axis=2)

# %%
x = np.linspace(-6,6, 50)
fx = norm.pdf(x, loc=0, scale=1)

# %%
filt = np.outer(fx, fx)

# %%
plt.imshow(filt, cmap='gray')

# %%
from scipy.signal import convolve2d

# %%
out = convolve2d(gray, filt)

# %%
plt.subplot(1,2,1)
plt.imshow(gray, cmap='jet')
plt.subplot(1,2,2)
plt.imshow(out, cmap='hot')  # blurred
